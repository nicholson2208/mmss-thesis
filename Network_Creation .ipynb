# %% [markdown]
# # Code for creating the set of graphs I will be using as the starting points
#
# ## Note: They should all be similar in some dimension, like average degree or something

# %%
 from igraph import *

# %%
small_world1 = Graph.Watts_Strogatz(1, 100, 3, 0.3)

# %%
plot(small_world1)

# %%
preferential_attachment1 = Graph.Barabasi(100, 3)

# %%
plot(preferential_attachment1)

# %%
random1 = Graph.Erdos_Renyi(100, m=400 )

# %%
plot(random1)

# %%
regular1 = Graph.Lattice([100], 4)

# %%
plot(regular1)
